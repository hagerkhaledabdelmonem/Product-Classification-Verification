# %% [markdown]
# # **Import libraries**

# %%
import os
import cv2
import numpy as np
import pandas as pd
import random
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from keras.src.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from keras.layers import *
from keras.models import Model
from keras.applications import ResNet50
from keras.models import Sequential
import time
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
random.seed(5)
np.random.seed(5)
tf.random.set_seed(5)

# %% [markdown]
# ## Load Data & Encoding labels ##

# %%
IMG_SIZE=256
#IMG_SIZE=224
data_path="/kaggle/input/product-classification/Product Classification/"

# %%
def Data_Preprocessing(root_folder,folder, IMG_SIZE):
    path_images = []
    labels = []

    # Iterate through each product folder
    for product_folder in os.listdir(root_folder):
        product_path = os.path.join(root_folder, product_folder)

        # List all image files in the training folder
        training_folder = os.path.join(product_path, folder)
        training_images = [os.path.join(training_folder, f) for f in os.listdir(training_folder)]
        # Add the paths and labels to the lists
        path_images.extend(training_images)
        labels.extend([int(product_folder)] * len(training_images))
    images=[]
    for path in path_images:
        img = cv2.imread(path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
        images.append(img)
    images = np.array(images, dtype='float32') / 255.0

    return images,labels

# %%
X_train, labels = Data_Preprocessing(data_path, 'Train',IMG_SIZE)
# Out:
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile

# %%
onehotencoder = OneHotEncoder()
labels = np.array(labels).reshape(-1,1)
labels = onehotencoder.fit_transform(labels).toarray()
y_train=labels

# %% [markdown]
# ## Augmentation For Train ##

# %%
training_datagen = ImageDataGenerator(
     horizontal_flip=True,
     vertical_flip=True,
     rotation_range=40,
     width_shift_range=0.2,
     height_shift_range=0.2,
     zoom_range=0.2,
     fill_mode="nearest",
)

training_datagen.fit(X_train)

# %% [markdown]
# # **CNN Model**

# %%
NUM_EPOCHS = 100
BATCH_SIZE = 64
Input_Shape=(IMG_SIZE,IMG_SIZE,3)

# %%
 model = Sequential([
        Conv2D(64, (3, 3), activation='relu', input_shape=Input_Shape),
        MaxPooling2D((2, 2), strides=2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2), strides=2),
        Conv2D(32, (3, 3), 1, activation='relu'),
        MaxPooling2D(),
        Conv2D(32, (3, 3), 1, activation='relu'),
        MaxPooling2D(),
        Flatten(),
        Dense(256, activation='relu'),
        Dense(20, activation='softmax')
    ])

# %% [markdown]
# # Compile Model

# %%
# opt = keras.optimizers.Adam(learning_rate=1e-5)
# model.compile(optimizer=opt,
#               loss=tf.losses.categorical_crossentropy,
#               metrics=['accuracy'])

model.compile(optimizer='adam',
              loss=tf.losses.categorical_crossentropy,
              metrics=['accuracy'])

# %%
start_train = time.time()

# %% [markdown]
# # Fit Model

# %%
history=model.fit(training_datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),epochs=NUM_EPOCHS)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 12s 238ms/step - loss: 3.4407 - accuracy: 0.0286
# Epoch 2/100
# 3/3 [==============================] - 2s 936ms/step - loss: 3.3580 - accuracy: 0.0929
# Epoch 3/100
# 3/3 [==============================] - 2s 492ms/step - loss: 3.3901 - accuracy: 0.1143
# Epoch 4/100
# 3/3 [==============================] - 2s 519ms/step - loss: 3.2092 - accuracy: 0.1143
# Epoch 5/100
# 3/3 [==============================] - 2s 563ms/step - loss: 2.9263 - accuracy: 0.1643
# Epoch 6/100
# 3/3 [==============================] - 2s 902ms/step - loss: 2.6938 - accuracy: 0.1429
# Epoch 7/100
# 3/3 [==============================] - 2s 497ms/step - loss: 2.4644 - accuracy: 0.2786
# Epoch 8/100
# 3/3 [==============================] - 2s 490ms/step - loss: 2.4366 - accuracy: 0.2286
# Epoch 9/100
# 3/3 [==============================] - 2s 524ms/step - loss: 2.3733 - accuracy: 0.2000
# Epoch 10/100
# 3/3 [==============================] - 2s 523ms/step - loss: 2.3616 - accuracy: 0.2214
# Epoch 11/100
# 3/3 [==============================] - 2s 914ms/step - loss: 2.3582 - accuracy: 0.1786
# Epoch 12/100
# 3/3 [==============================] - 2s 520ms/step - loss: 2.1574 - accuracy: 0.2786
# Epoch 13/100
# 3/3 [==============================] - 2s 899ms/step - loss: 2.0579 - accuracy: 0.3643
# Epoch 14/100
# 3/3 [==============================] - 2s 528ms/step - loss: 1.9329 - accuracy: 0.3714
# Epoch 15/100
# 3/3 [==============================] - 2s 526ms/step - loss: 1.8970 - accuracy: 0.4000
# Epoch 16/100
# 3/3 [==============================] - 2s 519ms/step - loss: 1.8167 - accuracy: 0.4000
# Epoch 17/100
# 3/3 [==============================] - 2s 521ms/step - loss: 1.8180 - accuracy: 0.3571
# Epoch 18/100
# 3/3 [==============================] - 2s 512ms/step - loss: 1.8191 - accuracy: 0.3643
# Epoch 19/100
# 3/3 [==============================] - 2s 514ms/step - loss: 1.7684 - accuracy: 0.3929
# Epoch 20/100
# 3/3 [==============================] - 2s 545ms/step - loss: 2.0092 - accuracy: 0.3857
# Epoch 21/100
# 3/3 [==============================] - 2s 524ms/step - loss: 1.7295 - accuracy: 0.4571
# Epoch 22/100
# 3/3 [==============================] - 2s 919ms/step - loss: 1.3643 - accuracy: 0.5071
# Epoch 23/100
# 3/3 [==============================] - 2s 903ms/step - loss: 1.5912 - accuracy: 0.4571
# Epoch 24/100
# 3/3 [==============================] - 2s 903ms/step - loss: 1.5465 - accuracy: 0.5000
# Epoch 25/100
# 3/3 [==============================] - 2s 902ms/step - loss: 1.3155 - accuracy: 0.5000
# Epoch 26/100
# 3/3 [==============================] - 2s 917ms/step - loss: 1.2088 - accuracy: 0.6000
# Epoch 27/100
# 3/3 [==============================] - 2s 504ms/step - loss: 1.1415 - accuracy: 0.5357
# Epoch 28/100
# 3/3 [==============================] - 2s 902ms/step - loss: 1.1189 - accuracy: 0.5786
# Epoch 29/100
# 3/3 [==============================] - 2s 526ms/step - loss: 1.1157 - accuracy: 0.6357
# Epoch 30/100
# 3/3 [==============================] - 2s 517ms/step - loss: 1.0636 - accuracy: 0.6571
# Epoch 31/100
# 3/3 [==============================] - 2s 902ms/step - loss: 1.0831 - accuracy: 0.6071
# Epoch 32/100
# 3/3 [==============================] - 2s 919ms/step - loss: 1.0431 - accuracy: 0.6429
# Epoch 33/100
# 3/3 [==============================] - 2s 901ms/step - loss: 1.4524 - accuracy: 0.5714
# Epoch 34/100
# 3/3 [==============================] - 2s 900ms/step - loss: 1.8624 - accuracy: 0.4786
# Epoch 35/100
# 3/3 [==============================] - 2s 903ms/step - loss: 1.8026 - accuracy: 0.5000
# Epoch 36/100
# 3/3 [==============================] - 2s 518ms/step - loss: 2.5767 - accuracy: 0.4071
# Epoch 37/100
# 3/3 [==============================] - 2s 518ms/step - loss: 1.7848 - accuracy: 0.5714
# Epoch 38/100
# 3/3 [==============================] - 2s 486ms/step - loss: 1.5476 - accuracy: 0.5643
# Epoch 39/100
# 3/3 [==============================] - 2s 897ms/step - loss: 2.7642 - accuracy: 0.3929
# Epoch 40/100
# 3/3 [==============================] - 2s 491ms/step - loss: 2.1877 - accuracy: 0.4643
# Epoch 41/100
# 3/3 [==============================] - 2s 511ms/step - loss: 1.7881 - accuracy: 0.5286
# Epoch 42/100
# 3/3 [==============================] - 2s 525ms/step - loss: 1.5986 - accuracy: 0.6000
# Epoch 43/100
# 3/3 [==============================] - 2s 517ms/step - loss: 1.8575 - accuracy: 0.5571
# Epoch 44/100
# 3/3 [==============================] - 2s 490ms/step - loss: 1.4729 - accuracy: 0.6000
# Epoch 45/100
# 3/3 [==============================] - 2s 492ms/step - loss: 1.4250 - accuracy: 0.5857
# Epoch 46/100
# 3/3 [==============================] - 2s 905ms/step - loss: 1.6086 - accuracy: 0.5500
# Epoch 47/100
# 3/3 [==============================] - 2s 500ms/step - loss: 1.7248 - accuracy: 0.5357
# Epoch 48/100
# 3/3 [==============================] - 2s 907ms/step - loss: 1.2101 - accuracy: 0.6071
# Epoch 49/100
# 3/3 [==============================] - 2s 894ms/step - loss: 1.2133 - accuracy: 0.6643
# Epoch 50/100
# 3/3 [==============================] - 2s 897ms/step - loss: 1.1352 - accuracy: 0.6929
# Epoch 51/100
# 3/3 [==============================] - 2s 486ms/step - loss: 0.8384 - accuracy: 0.7071
# Epoch 52/100
# 3/3 [==============================] - 2s 939ms/step - loss: 0.9557 - accuracy: 0.7000
# Epoch 53/100
# 3/3 [==============================] - 2s 915ms/step - loss: 1.0942 - accuracy: 0.6214
# Epoch 54/100
# 3/3 [==============================] - 2s 518ms/step - loss: 0.9216 - accuracy: 0.7143
# Epoch 55/100
# 3/3 [==============================] - 2s 913ms/step - loss: 0.9243 - accuracy: 0.6500
# Epoch 56/100
# 3/3 [==============================] - 2s 517ms/step - loss: 1.1030 - accuracy: 0.6000
# Epoch 57/100
# 3/3 [==============================] - 2s 496ms/step - loss: 0.9240 - accuracy: 0.7286
# Epoch 58/100
# 3/3 [==============================] - 2s 911ms/step - loss: 0.7977 - accuracy: 0.6857
# Epoch 59/100
# 3/3 [==============================] - 2s 491ms/step - loss: 0.6400 - accuracy: 0.7714
# Epoch 60/100
# 3/3 [==============================] - 2s 903ms/step - loss: 0.7203 - accuracy: 0.7571
# Epoch 61/100
# 3/3 [==============================] - 2s 522ms/step - loss: 1.0192 - accuracy: 0.6571
# Epoch 62/100
# 3/3 [==============================] - 2s 492ms/step - loss: 1.0303 - accuracy: 0.6643
# Epoch 63/100
# 3/3 [==============================] - 2s 520ms/step - loss: 0.9691 - accuracy: 0.6929
# Epoch 64/100
# 3/3 [==============================] - 2s 487ms/step - loss: 0.8841 - accuracy: 0.7357
# Epoch 65/100
# 3/3 [==============================] - 2s 516ms/step - loss: 1.0393 - accuracy: 0.6786
# Epoch 66/100
# 3/3 [==============================] - 2s 489ms/step - loss: 1.1470 - accuracy: 0.6857
# Epoch 67/100
# 3/3 [==============================] - 2s 555ms/step - loss: 1.0940 - accuracy: 0.6286
# Epoch 68/100
# 3/3 [==============================] - 2s 511ms/step - loss: 1.7181 - accuracy: 0.5929
# Epoch 69/100
# 3/3 [==============================] - 2s 499ms/step - loss: 0.9731 - accuracy: 0.7143
# Epoch 70/100
# 3/3 [==============================] - 2s 495ms/step - loss: 1.2541 - accuracy: 0.6571
# Epoch 71/100
# 3/3 [==============================] - 2s 515ms/step - loss: 1.2307 - accuracy: 0.6214
# Epoch 72/100
# 3/3 [==============================] - 2s 515ms/step - loss: 1.3880 - accuracy: 0.5929
# Epoch 73/100
# 3/3 [==============================] - 2s 519ms/step - loss: 1.1853 - accuracy: 0.6286
# Epoch 74/100
# 3/3 [==============================] - 2s 515ms/step - loss: 1.3087 - accuracy: 0.6214
# Epoch 75/100
# 3/3 [==============================] - 2s 902ms/step - loss: 1.4869 - accuracy: 0.7000
# Epoch 76/100
# 3/3 [==============================] - 2s 491ms/step - loss: 1.1207 - accuracy: 0.6429
# Epoch 77/100
# 3/3 [==============================] - 2s 489ms/step - loss: 0.9213 - accuracy: 0.7214
# Epoch 78/100
# 3/3 [==============================] - 2s 521ms/step - loss: 1.1850 - accuracy: 0.6571
# Epoch 79/100
# 3/3 [==============================] - 2s 522ms/step - loss: 1.2136 - accuracy: 0.6714
# Epoch 80/100
# 3/3 [==============================] - 2s 521ms/step - loss: 1.6430 - accuracy: 0.6000
# Epoch 81/100
# 3/3 [==============================] - 2s 901ms/step - loss: 1.3223 - accuracy: 0.6429
# Epoch 82/100
# 3/3 [==============================] - 2s 918ms/step - loss: 1.5441 - accuracy: 0.5571
# Epoch 83/100
# 3/3 [==============================] - 2s 512ms/step - loss: 1.2977 - accuracy: 0.6500
# Epoch 84/100
# 3/3 [==============================] - 2s 500ms/step - loss: 1.1492 - accuracy: 0.6857
# Epoch 85/100
# 3/3 [==============================] - 2s 901ms/step - loss: 1.3042 - accuracy: 0.6286
# Epoch 86/100
# 3/3 [==============================] - 2s 902ms/step - loss: 1.3540 - accuracy: 0.6857
# Epoch 87/100
# 3/3 [==============================] - 2s 515ms/step - loss: 1.1429 - accuracy: 0.6714
# Epoch 88/100
# 3/3 [==============================] - 2s 912ms/step - loss: 0.8313 - accuracy: 0.6857
# Epoch 89/100
# 3/3 [==============================] - 2s 519ms/step - loss: 0.7543 - accuracy: 0.7714
# Epoch 90/100
# 3/3 [==============================] - 2s 517ms/step - loss: 0.9235 - accuracy: 0.7143
# Epoch 91/100
# 3/3 [==============================] - 2s 509ms/step - loss: 1.1933 - accuracy: 0.6429
# Epoch 92/100
# 3/3 [==============================] - 2s 521ms/step - loss: 0.7809 - accuracy: 0.7143
# Epoch 93/100
# 3/3 [==============================] - 2s 487ms/step - loss: 0.7649 - accuracy: 0.7571
# Epoch 94/100
# 3/3 [==============================] - 2s 910ms/step - loss: 1.1007 - accuracy: 0.7071
# Epoch 95/100
# 3/3 [==============================] - 2s 489ms/step - loss: 1.5345 - accuracy: 0.6643
# Epoch 96/100
# 3/3 [==============================] - 2s 523ms/step - loss: 1.2335 - accuracy: 0.6643
# Epoch 97/100
# 3/3 [==============================] - 2s 518ms/step - loss: 1.4210 - accuracy: 0.6000
# Epoch 98/100
# 3/3 [==============================] - 2s 550ms/step - loss: 1.0907 - accuracy: 0.6714
# Epoch 99/100
# 3/3 [==============================] - 2s 492ms/step - loss: 1.7231 - accuracy: 0.6500
# Epoch 100/100
# 3/3 [==============================] - 2s 516ms/step - loss: 1.4406 - accuracy: 0.6286

# %%
end_train = time.time()

# %%
model.save('CNN_Model.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # Plot the training accuracy and loss at each epoch #

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.title('Training loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = history.history['accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.title('Training accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # **Time of Training**

# %%
Training_time = end_train - start_train

# %%
print('Training Time CNN',Training_time)
# Out:
# Training Time CNN 211.09065461158752
