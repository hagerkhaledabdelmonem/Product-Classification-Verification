# %% [markdown]
# # **Import libraries**

# %%
import os
import cv2
import numpy as np
import pandas as pd
import random
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from keras.src.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from keras.layers import *
from keras.models import Model
from keras.applications import ResNet50
from keras.models import Sequential
import time

# %%
random.seed(5)
np.random.seed(5)
tf.random.set_seed(5)

# %% [markdown]
# ## Load Data & Encoding labels ##

# %%
#IMG_SIZE=256
IMG_SIZE=224
data_path="/kaggle/input/product-classification/Product Classification/"

# %%
def Data_Preprocessing(root_folder,folder, IMG_SIZE):
    path_images = []
    labels = []

    # Iterate through each product folder
    for product_folder in os.listdir(root_folder):
        product_path = os.path.join(root_folder, product_folder)

        # List all image files in the training folder
        training_folder = os.path.join(product_path, folder)
        training_images = [os.path.join(training_folder, f) for f in os.listdir(training_folder)]
        # Add the paths and labels to the lists
        path_images.extend(training_images)
        labels.extend([int(product_folder)] * len(training_images))
    images=[]
    for path in path_images:
        img = cv2.imread(path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
        images.append(img)
    images = np.array(images, dtype='float32') / 255.0

    return images,labels

# %%
X_train, labels = Data_Preprocessing(data_path, 'Train',IMG_SIZE)
# Out:
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile

# %%
onehotencoder = OneHotEncoder()
labels = np.array(labels).reshape(-1,1)
labels = onehotencoder.fit_transform(labels).toarray()
y_train=labels

# %% [markdown]
# ## Augmentation For Train ##

# %%
training_datagen = ImageDataGenerator(
     horizontal_flip=True,
     vertical_flip=True,
     rotation_range=40,
     width_shift_range=0.2,
     height_shift_range=0.2,
     zoom_range=0.2,
     fill_mode="nearest",
)

training_datagen.fit(X_train)

# %% [markdown]
# # **DenseNet Model**

# %%
NUM_EPOCHS = 100
BATCH_SIZE = 64
Input_Shape=(IMG_SIZE,IMG_SIZE,3)

# %%
base_model = keras.applications.DenseNet121(
    include_top=False,
    weights="imagenet",
    input_shape=Input_Shape,
)
for layer in base_model.layers:
    layer.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(20, activation='Softmax')(x)

model = Model(base_model.input, x)

# %% [markdown]
# # Compile Model

# %%
# opt = keras.optimizers.Adam(learning_rate=1e-5)
# model.compile(optimizer=opt,
#               loss=tf.losses.categorical_crossentropy,
#               metrics=['accuracy'])
model.compile(optimizer='adam',
              loss=tf.losses.categorical_crossentropy,
              metrics=['accuracy'])

# %%
start_train = time.time()

# %% [markdown]
# # Fit Model

# %%
history=model.fit(training_datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),epochs=NUM_EPOCHS)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 8s 330ms/step - loss: 3.2599 - accuracy: 0.0357
# Epoch 2/100
# 3/3 [==============================] - 2s 365ms/step - loss: 2.9413 - accuracy: 0.1214
# Epoch 3/100
# 3/3 [==============================] - 2s 409ms/step - loss: 2.7191 - accuracy: 0.2214
# Epoch 4/100
# 3/3 [==============================] - 2s 412ms/step - loss: 2.4946 - accuracy: 0.2857
# Epoch 5/100
# 3/3 [==============================] - 2s 385ms/step - loss: 2.3748 - accuracy: 0.2929
# Epoch 6/100
# 3/3 [==============================] - 2s 383ms/step - loss: 2.1619 - accuracy: 0.4286
# Epoch 7/100
# 3/3 [==============================] - 2s 724ms/step - loss: 1.9799 - accuracy: 0.5286
# Epoch 8/100
# 3/3 [==============================] - 1s 369ms/step - loss: 1.8674 - accuracy: 0.5929
# Epoch 9/100
# 3/3 [==============================] - 2s 726ms/step - loss: 1.7103 - accuracy: 0.6357
# Epoch 10/100
# 3/3 [==============================] - 2s 720ms/step - loss: 1.5705 - accuracy: 0.7500
# Epoch 11/100
# 3/3 [==============================] - 2s 733ms/step - loss: 1.5416 - accuracy: 0.7286
# Epoch 12/100
# 3/3 [==============================] - 2s 398ms/step - loss: 1.3809 - accuracy: 0.8357
# Epoch 13/100
# 3/3 [==============================] - 2s 776ms/step - loss: 1.2416 - accuracy: 0.8643
# Epoch 14/100
# 3/3 [==============================] - 2s 721ms/step - loss: 1.1655 - accuracy: 0.9000
# Epoch 15/100
# 3/3 [==============================] - 2s 399ms/step - loss: 1.1230 - accuracy: 0.8429
# Epoch 16/100
# 3/3 [==============================] - 2s 713ms/step - loss: 1.0626 - accuracy: 0.8857
# Epoch 17/100
# 3/3 [==============================] - 2s 396ms/step - loss: 0.9753 - accuracy: 0.8929
# Epoch 18/100
# 3/3 [==============================] - 2s 384ms/step - loss: 0.8816 - accuracy: 0.9214
# Epoch 19/100
# 3/3 [==============================] - 2s 735ms/step - loss: 0.8246 - accuracy: 0.9500
# Epoch 20/100
# 3/3 [==============================] - 2s 415ms/step - loss: 0.7771 - accuracy: 0.9786
# Epoch 21/100
# 3/3 [==============================] - 2s 705ms/step - loss: 0.7246 - accuracy: 0.9643
# Epoch 22/100
# 3/3 [==============================] - 2s 400ms/step - loss: 0.7004 - accuracy: 0.9643
# Epoch 23/100
# 3/3 [==============================] - 2s 387ms/step - loss: 0.6494 - accuracy: 0.9571
# Epoch 24/100
# 3/3 [==============================] - 2s 409ms/step - loss: 0.6487 - accuracy: 0.9857
# Epoch 25/100
# 3/3 [==============================] - 2s 420ms/step - loss: 0.5592 - accuracy: 0.9714
# Epoch 26/100
# 3/3 [==============================] - 2s 438ms/step - loss: 0.5512 - accuracy: 1.0000
# Epoch 27/100
# 3/3 [==============================] - 2s 372ms/step - loss: 0.5437 - accuracy: 0.9786
# Epoch 28/100
# 3/3 [==============================] - 2s 458ms/step - loss: 0.5155 - accuracy: 0.9857
# Epoch 29/100
# 3/3 [==============================] - 2s 469ms/step - loss: 0.5304 - accuracy: 0.9786
# Epoch 30/100
# 3/3 [==============================] - 2s 375ms/step - loss: 0.4759 - accuracy: 0.9643
# Epoch 31/100
# 3/3 [==============================] - 1s 367ms/step - loss: 0.4577 - accuracy: 0.9643
# Epoch 32/100
# 3/3 [==============================] - 2s 396ms/step - loss: 0.4277 - accuracy: 0.9857
# Epoch 33/100
# 3/3 [==============================] - 2s 387ms/step - loss: 0.3827 - accuracy: 0.9714
# Epoch 34/100
# 3/3 [==============================] - 2s 402ms/step - loss: 0.4307 - accuracy: 0.9857
# Epoch 35/100
# 3/3 [==============================] - 2s 426ms/step - loss: 0.3691 - accuracy: 0.9857
# Epoch 36/100
# 3/3 [==============================] - 2s 698ms/step - loss: 0.3702 - accuracy: 0.9857
# Epoch 37/100
# 3/3 [==============================] - 2s 422ms/step - loss: 0.3401 - accuracy: 1.0000
# Epoch 38/100
# 3/3 [==============================] - 2s 403ms/step - loss: 0.3494 - accuracy: 0.9929
# Epoch 39/100
# 3/3 [==============================] - 2s 414ms/step - loss: 0.3111 - accuracy: 0.9929
# Epoch 40/100
# 3/3 [==============================] - 2s 424ms/step - loss: 0.3472 - accuracy: 0.9929
# Epoch 41/100
# 3/3 [==============================] - 2s 411ms/step - loss: 0.3170 - accuracy: 0.9857
# Epoch 42/100
# 3/3 [==============================] - 2s 718ms/step - loss: 0.2996 - accuracy: 0.9857
# Epoch 43/100
# 3/3 [==============================] - 2s 715ms/step - loss: 0.2868 - accuracy: 0.9929
# Epoch 44/100
# 3/3 [==============================] - 1s 358ms/step - loss: 0.2813 - accuracy: 1.0000
# Epoch 45/100
# 3/3 [==============================] - 2s 374ms/step - loss: 0.2837 - accuracy: 1.0000
# Epoch 46/100
# 3/3 [==============================] - 2s 715ms/step - loss: 0.2484 - accuracy: 1.0000
# Epoch 47/100
# 3/3 [==============================] - 2s 708ms/step - loss: 0.2761 - accuracy: 0.9857
# Epoch 48/100
# 3/3 [==============================] - 2s 413ms/step - loss: 0.2337 - accuracy: 1.0000
# Epoch 49/100
# 3/3 [==============================] - 2s 732ms/step - loss: 0.2407 - accuracy: 1.0000
# Epoch 50/100
# 3/3 [==============================] - 2s 393ms/step - loss: 0.2297 - accuracy: 0.9857
# Epoch 51/100
# 3/3 [==============================] - 2s 417ms/step - loss: 0.2309 - accuracy: 1.0000
# Epoch 52/100
# 3/3 [==============================] - 2s 372ms/step - loss: 0.2400 - accuracy: 0.9929
# Epoch 53/100
# 3/3 [==============================] - 2s 412ms/step - loss: 0.2361 - accuracy: 0.9929
# Epoch 54/100
# 3/3 [==============================] - 2s 384ms/step - loss: 0.2049 - accuracy: 1.0000
# Epoch 55/100
# 3/3 [==============================] - 2s 720ms/step - loss: 0.2050 - accuracy: 0.9857
# Epoch 56/100
# 3/3 [==============================] - 2s 381ms/step - loss: 0.1996 - accuracy: 1.0000
# Epoch 57/100
# 3/3 [==============================] - 2s 409ms/step - loss: 0.2139 - accuracy: 0.9929
# Epoch 58/100
# 3/3 [==============================] - 2s 458ms/step - loss: 0.1975 - accuracy: 1.0000
# Epoch 59/100
# 3/3 [==============================] - 2s 397ms/step - loss: 0.1914 - accuracy: 1.0000
# Epoch 60/100
# 3/3 [==============================] - 2s 415ms/step - loss: 0.1881 - accuracy: 1.0000
# Epoch 61/100
# 3/3 [==============================] - 2s 402ms/step - loss: 0.1662 - accuracy: 1.0000
# Epoch 62/100
# 3/3 [==============================] - 2s 389ms/step - loss: 0.1750 - accuracy: 1.0000
# Epoch 63/100
# 3/3 [==============================] - 2s 399ms/step - loss: 0.1611 - accuracy: 1.0000
# Epoch 64/100
# 3/3 [==============================] - 2s 734ms/step - loss: 0.1738 - accuracy: 0.9929
# Epoch 65/100
# 3/3 [==============================] - 1s 360ms/step - loss: 0.1528 - accuracy: 1.0000
# Epoch 66/100
# 3/3 [==============================] - 2s 395ms/step - loss: 0.1636 - accuracy: 1.0000
# Epoch 67/100
# 3/3 [==============================] - 2s 374ms/step - loss: 0.1564 - accuracy: 0.9929
# Epoch 68/100
# 3/3 [==============================] - 2s 394ms/step - loss: 0.1673 - accuracy: 0.9929
# Epoch 69/100
# 3/3 [==============================] - 2s 720ms/step - loss: 0.1599 - accuracy: 1.0000
# Epoch 70/100
# 3/3 [==============================] - 2s 396ms/step - loss: 0.1439 - accuracy: 1.0000
# Epoch 71/100
# 3/3 [==============================] - 2s 379ms/step - loss: 0.1486 - accuracy: 1.0000
# Epoch 72/100
# 3/3 [==============================] - 2s 388ms/step - loss: 0.1612 - accuracy: 1.0000
# Epoch 73/100
# 3/3 [==============================] - 2s 730ms/step - loss: 0.1401 - accuracy: 1.0000
# Epoch 74/100
# 3/3 [==============================] - 2s 393ms/step - loss: 0.1152 - accuracy: 1.0000
# Epoch 75/100
# 3/3 [==============================] - 2s 377ms/step - loss: 0.1353 - accuracy: 0.9929
# Epoch 76/100
# 3/3 [==============================] - 2s 408ms/step - loss: 0.1397 - accuracy: 1.0000
# Epoch 77/100
# 3/3 [==============================] - 1s 371ms/step - loss: 0.1248 - accuracy: 1.0000
# Epoch 78/100
# 3/3 [==============================] - 2s 369ms/step - loss: 0.1457 - accuracy: 1.0000
# Epoch 79/100
# 3/3 [==============================] - 2s 433ms/step - loss: 0.1294 - accuracy: 0.9929
# Epoch 80/100
# 3/3 [==============================] - 2s 365ms/step - loss: 0.1098 - accuracy: 1.0000
# Epoch 81/100
# 3/3 [==============================] - 2s 692ms/step - loss: 0.1246 - accuracy: 0.9929
# Epoch 82/100
# 3/3 [==============================] - 2s 393ms/step - loss: 0.1145 - accuracy: 1.0000
# Epoch 83/100
# 3/3 [==============================] - 2s 405ms/step - loss: 0.1131 - accuracy: 0.9929
# Epoch 84/100
# 3/3 [==============================] - 2s 714ms/step - loss: 0.1206 - accuracy: 1.0000
# Epoch 85/100
# 3/3 [==============================] - 2s 709ms/step - loss: 0.1065 - accuracy: 0.9929
# Epoch 86/100
# 3/3 [==============================] - 2s 393ms/step - loss: 0.1124 - accuracy: 1.0000
# Epoch 87/100
# 3/3 [==============================] - 2s 394ms/step - loss: 0.1127 - accuracy: 1.0000
# Epoch 88/100
# 3/3 [==============================] - 2s 398ms/step - loss: 0.1039 - accuracy: 1.0000
# Epoch 89/100
# 3/3 [==============================] - 1s 359ms/step - loss: 0.1017 - accuracy: 1.0000
# Epoch 90/100
# 3/3 [==============================] - 1s 362ms/step - loss: 0.0991 - accuracy: 0.9929
# Epoch 91/100
# 3/3 [==============================] - 2s 697ms/step - loss: 0.0962 - accuracy: 1.0000
# Epoch 92/100
# 3/3 [==============================] - 2s 708ms/step - loss: 0.0979 - accuracy: 1.0000
# Epoch 93/100
# 3/3 [==============================] - 2s 394ms/step - loss: 0.0916 - accuracy: 1.0000
# Epoch 94/100
# 3/3 [==============================] - 2s 697ms/step - loss: 0.0972 - accuracy: 1.0000
# Epoch 95/100
# 3/3 [==============================] - 2s 396ms/step - loss: 0.1085 - accuracy: 0.9857
# Epoch 96/100
# 3/3 [==============================] - 2s 720ms/step - loss: 0.0941 - accuracy: 1.0000
# Epoch 97/100
# 3/3 [==============================] - 2s 719ms/step - loss: 0.0884 - accuracy: 0.9929
# Epoch 98/100
# 3/3 [==============================] - 2s 387ms/step - loss: 0.0824 - accuracy: 1.0000
# Epoch 99/100
# 3/3 [==============================] - 2s 424ms/step - loss: 0.0881 - accuracy: 1.0000
# Epoch 100/100
# 3/3 [==============================] - 2s 707ms/step - loss: 0.0902 - accuracy: 0.9929

# %%
end_train = time.time()

# %%
model.save('DenseNet_Model.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # Plot the training accuracy and loss at each epoch #

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.title('Training loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = history.history['accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.title('Training accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # **Time of Training**

# %%
Training_time = end_train - start_train

# %%
print('Training Time DesneNet',Training_time)
# Out:
# Training Time DesneNet 166.33709335327148
